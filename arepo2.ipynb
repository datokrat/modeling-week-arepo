# %%
import arepo as ar
import arviz as az
import matplotlib.pyplot as plt
# Out:
# Ray module not found. Multiprocessing features are not available

# %%
idata = ar.inverse_uq(0.5, 20, 5, 20, 5, 0.5, 1.0, 0.125, 0.1)
# Out:
# /home/paul/temp/jupyter-kernels/dasci/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:592: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x1) - f0
# /home/paul/coding/modeling-week/modeling-week-arepo/Riemann.py:30: RuntimeWarning: invalid value encountered in scalar power
#   return ( 2.0 * a_K / ( gamma - 1.0 ) ) * ( ( pres / W_K[2] )**exponent - 1.0 )
# /home/paul/coding/modeling-week/modeling-week-arepo/Riemann.py:50: RuntimeWarning: invalid value encountered in scalar power
#   return ( pres / W_K[2] )**exponent / W_K[0] / a_K
# /home/paul/temp/jupyter-kernels/dasci/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:592: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x1) - f0
# /home/paul/coding/modeling-week/modeling-week-arepo/Riemann.py:30: RuntimeWarning: invalid value encountered in scalar power
#   return ( 2.0 * a_K / ( gamma - 1.0 ) ) * ( ( pres / W_K[2] )**exponent - 1.0 )
# ...

# %%
az.summary(idata)
# Out:
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  0.673  0.258   0.171    1.000      0.010    0.007     727.0    1104.0
# x1  0.833  0.132   0.587    1.000      0.005    0.004     645.0     825.0
# x2  0.310  0.260   0.000    0.850      0.011    0.008     612.0     959.0
# x3  0.394  0.160   0.092    0.685      0.006    0.004     773.0    1332.0
#
#     r_hat
# x0   1.00
# x1   1.01
# x2   1.00
# x3   1.00

# %%
az.plot_trace(idata)
plt.tight_layout()
plt.show()
