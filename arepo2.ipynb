# %%
import arepo as ar
import arviz as az
import matplotlib.pyplot as plt

# %%
idata = ar.inverse_uq(0.5, 20, 5, 20, 5, 0.5, 1.0, 0.125, 0.1)
# Out:
# /home/paul/temp/jupyter-kernels/dasci/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:592: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x1) - f0
# /home/paul/temp/jupyter-kernels/dasci/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:592: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x1) - f0
# /home/paul/temp/jupyter-kernels/dasci/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:592: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x1) - f0
# Sampling chain 1/2
# Running chain, α = 0.05:   0%|          | 0/12000 [00:00<?, ?it/s]/home/paul/coding/modeling-week/modeling-week-arepo/Riemann.py:30: RuntimeWarning: invalid value encountered in scalar power
#   return ( 2.0 * a_K / ( gamma - 1.0 ) ) * ( ( pres / W_K[2] )**exponent - 1.0 )
# /home/paul/coding/modeling-week/modeling-week-arepo/Riemann.py:50: RuntimeWarning: invalid value encountered in scalar power
# ...

# %%
az.summary(idata)
# Out:
#      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# x0  0.600  0.228   0.237    0.998      0.007    0.005    1030.0    1971.0
# x1  0.868  0.104   0.679    1.000      0.004    0.003     905.0    1262.0
# x2  0.451  0.274   0.002    0.901      0.009    0.006     858.0    1245.0
# x3  0.228  0.126   0.003    0.435      0.005    0.003     790.0    1209.0
#
#     r_hat
# x0    1.0
# x1    1.0
# x2    1.0
# x3    1.0

# %%
az.plot_trace(idata)
plt.tight_layout()
plt.show()

# %%
s1 = az.summary(ar.inverse_uq(0.1, 20, 5, 20, 5, 0.5, 1.0, 0.125, 0.1))
s2 = az.summary(ar.inverse_uq(0.3, 20, 5, 20, 5, 0.5, 1.0, 0.125, 0.1))
s3 = az.summary(ar.inverse_uq(0.5, 20, 5, 20, 5, 0.5, 1.0, 0.125, 0.1))
s4 = az.summary(ar.inverse_uq(0.7, 20, 5, 20, 5, 0.5, 1.0, 0.125, 0.1))
s5 = az.summary(ar.inverse_uq(0.9, 20, 5, 20, 5, 0.5, 1.0, 0.125, 0.1))

print(s1)
print(s2)
print(s3)
print(s4)
print(s5)
# Out:
# /home/paul/temp/jupyter-kernels/dasci/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:592: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x1) - f0
# /home/paul/temp/jupyter-kernels/dasci/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:592: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x1) - f0
# /home/paul/temp/jupyter-kernels/dasci/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:592: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x1) - f0
# /home/paul/temp/jupyter-kernels/dasci/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:592: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x1) - f0
# Sampling chain 1/2
# Running chain, α = 0.17:   0%|          | 0/12000 [00:00<?, ?it/s]/home/paul/coding/modeling-week/modeling-week-arepo/Riemann.py:30: RuntimeWarning: invalid value encountered in scalar power
# ...
